# %%
import asyncio
import aiohttp
import curses
from bs4 import BeautifulSoup

# %%
import re

def format_film(soup):
    description = soup.find(id='event-description')
    if description:
        description = description.contents[2].strip()
    
    genres = soup.find('td', class_='genre')
    if genres:
        genres = genres.select('a', class_='genre');
        if genres:
            genres = list(map(lambda x: x.text, genres))
    
    year = soup.find('td', class_='year')
    if year:
        year=year.text
    
    country = soup.find('td', class_='author')
    if country:
        country = country.text.strip()
    
    duration = soup.find('td', class_='duration')
    if duration:
        duration_re = re.compile('([0-9]+)')
        duration = re.search(duration_re, duration.text.strip()).group(1)
    
    producer_re = re.compile('Режиссер: (.*)')
    producer = soup.find(text=producer_re) 
    if producer:
        producer = re.search(producer_re, producer).group(1)

    actors_re = re.compile('В ролях: (.*)')
    actors = soup.find_all('p')
    actors = [p for p in actors if p.find(text=actors_re)]; # find if there a valid p
    if len(actors):
        actors = actors[0].text
        actors_str = re.search(actors_re, actors).group(1)
        actors = list(map(lambda x: x.strip(), actors_str.split(',')))
    
    rating = soup.find(class_='rating-big__value')
    if rating:
        rating = rating.text
    
    return {
        'description': description,
        'genres': genres,
        'year': year,
        'country': country,
        'duration': duration,
        'producer': producer,
        'actors': actors,
        'rating': rating,
    }

# %%
from pipetools import pipe
from IPython.display import clear_output

flatten = lambda list_: [item for sublist in list_ for item in sublist]
get_li_list = (pipe 
               | (map, lambda x: x.find_all('li', class_='lists__li'))
               | list 
               | flatten
              );

async def fetch_html(url, session):
    response = await session.get(url)
    return await response.text()

async def get_soup_from_url(url, session):
    html = await fetch_html(url, session)
    return BeautifulSoup(html, 'html.parser')

async def get_films_list(url, session):
    soup = await get_soup_from_url(url, session)
    ul_list = soup.find_all('ul', class_='list_afisha')
    return get_li_list(ul_list)

async def fetch_film_data(url, session):
    data = await get_soup_from_url(url, session)
    return format_film(data)

async def get_film_data(film_soup, index, session):
        a_name = film_soup.find('a', class_='name')
        img = film_soup.find('img')

        if not a_name:
            return

        link_to_film = a_name['href']

        film_data = await fetch_film_data(link_to_film, session)

        result = {
            'name': a_name.text.strip(),
            'img_url': img['src'],
            'url': link_to_film,
        }
        result.update(film_data)
        return result

# %%
from aiohttp import ClientSession

async with ClientSession() as session:
    films_list = await get_films_list('https://afisha.tut.by/day/film/2020-11-01/2020-11-28/', session)
    
    films_list_len = len(films_list)
    processed = []

    async def get_film_data_with_logging(film_soup, index, session):
        global films_list_len

        film = await get_film_data(film_soup, index, session)
        processed.append(index)

        clear_output(wait=True)
        print(f'Finished processing {len(processed)} of {films_list_len} films')

        return film
    
    films = await asyncio.gather(
        *[get_film_data_with_logging(film_soup, index, session) for index, film_soup in enumerate(films_list)]
    )
# Out:
# Finished processing 93 of 93 films

# %%
import pandas as pd

df_films = pd.DataFrame(films)

# %%
df_films
# Out:
#                                               name  \
# 0                                   Взаперти (SUB)
# 1   TheatreHD: Золотая маска: Иранская конференция
# 2                             Непосредственно Каха
# 3                             Афера по-голливудски
# 4                                         Взаперти
# ..                                             ...
# 88                TheatreHD: Золотая маска: Гамлет
# 89                     TheatreHD: Волшебная флейта
# 90                            TheatreHD: Щелкунчик
# 91                                TheatreHD: Дрянь
# 92                    TheatreHD: Щелкунчик (балет)
#
#                                               img_url  \
# 0   https://img.afisha.tut.by/static/media/176x0ec...
# 1   https://img.afisha.tut.by/static/media/176x0ec...
# 2   https://img.afisha.tut.by/static/media/176x0ec...
# 3   https://img.afisha.tut.by/static/media/176x0ec...
# 4   https://img.afisha.tut.by/static/media/176x0ec...
# ..                                                ...
# 88  https://img.afisha.tut.by/static/media/176x0ec...
# 89  https://img.afisha.tut.by/static/media/176x0ec...
# 90  https://img.afisha.tut.by/static/media/176x0ec...
# 91  https://img.afisha.tut.by/static/media/176x0ec...
# 92  https://img.afisha.tut.by/static/media/176x0ec...
#
#                                                   url  \
# 0            https://afisha.tut.by/film/vzaperti-sub/
# 1   https://afisha.tut.by/film/theatrehd_zolotaya_...
# 2   https://afisha.tut.by/film/neposredstvenno_kakha/
# 3    https://afisha.tut.by/film/afera-po-gollivudski/
# 4                https://afisha.tut.by/film/vzaperti/
# ..                                                ...
# 88  https://afisha.tut.by/film/theatrehd-zolotaya-...
# 89  https://afisha.tut.by/film/theatrehd_volshebna...
# 90  https://afisha.tut.by/film/theatrehd-shchelkun...
# 91        https://afisha.tut.by/film/theatrehd-dryan/
# 92  https://afisha.tut.by/film/theatrehd-shchelkun...
#
#                                           description  \
# 0   Гиперзаботливая мать Диана Шерман растит дочь ...
# 1   Эта постановка по пьесе знаменитого драматурга...
# 2   Каха запал на прекрасную Софу, но, чтобы подоб...
# 3   Макс Барбер – типичный голливудский продюсер, ...
# 4   Гиперзаботливая мать Диана Шерман растит дочь ...
# ..                                                ...
# 88    Театр: Малый драматический театр — Театр Европы
# 89
# 90                              Балет в 2-х действиях
# 91                             Страна: Великобритания
# 92                                 *Прямая трансляция
#
#                         genres  year         country duration      producer  \
# 0   [Детектив, Триллер, Ужасы]  2020             США       90  Аниш Чаганти
# 1                         None  2020            None      120          None
# 2                    [Комедия]  2020          Россия      117
# 3            [Боевик, Комедия]  2020             США      110  Джордж Галло
# 4   [Детектив, Триллер, Ужасы]  2020             США       90  Аниш Чаганти
# ..                         ...   ...             ...      ...           ...
# 88                        None  2020          Россия      120     Лев Додин
# 89                        None  None            None     None          None
# 90                        None  2018            None      144          None
# 91                        None  None  Великобритания       84          None
# 92                        None  2014          Россия      144          None
#
#                                                actors rating
# 0   [Сара Полсон, Кира Аллен, Онали Эймс, Пэт Хили...   None
# 1                                                  []   None
# 2   [Артем Карокозян, Артем Калайджян, Марина Кале...    6,3
# 3   [Роберт Де Ниро, Морган Фриман, Томми Ли Джонс...    6,3
# 4   [Сара Полсон, Кира Аллен, Онали Эймс, Пэт Хили...    6,7
# ..                                                ...    ...
# 88                                                 []   None
# 89                                                 []    6,7
# 90                                                 []   10,0
# 91                                                 []    5,0
# 92  [Денис Родькин, Анна Никулина, Андрей Меркурье...   None
#
# [93 rows x 11 columns]
